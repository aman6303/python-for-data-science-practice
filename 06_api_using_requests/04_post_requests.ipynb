# %%
import requests

# %% [raw]
# post -- update , send ,modify ,change
#
# # if api alllow

# %%
response=requests.post("http://httpbin.org/post")

# %%
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-68ff84e5-3c9ca68e61fcc80f079dcff5"
#   },
#   "json": null,
#   "origin": "223.181.103.203",
#   "url": "http://httpbin.org/post"
# }

# %%
response.url
# Out:
# 'http://httpbin.org/post'

# %%
#response=requests.post("url",data= inform of pyton dict)

# %%
#method 2
response=requests.post("http://httpbin.org/post",data={"key":"val1","key2":"val2"})
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "val1",
#     "key2": "val2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "18",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-68ff85cb-72d3a2087d11a19045ba11bc"
#   },
#   "json": null,
#   "origin": "223.181.103.203",
#   "url": "http://httpbin.org/post"
# }

# %%
response=requests.post("http://httpbin.org/post",data={"key":"val1","key2":["val2","val3"]})
print(response)
print(response.text)
# Out:
# <Response [503]>
# <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# </body>
# </html>

# %%
#method 2
#passing list of tuples -- other option

response=requests.post("http://httpbin.org/post",data=[("key1","val1"),("key1","val2"),("key3","val3")])
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "val1",
#       "val2"
#     ],
#     "key3": "val3"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "29",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-68ff8717-40b35c261d0dca84580ee88e"
#   },
#   "json": null,
#   "origin": "223.181.103.203",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# # working on jsonplaceholder

# %%
response=requests.post("https://jsonplaceholder.typicode.com/posts")
print(response)
print(response.text)
# Out:
# <Response [201]>
# {
#   "id": 101
# }

# %%
response=requests.post("https://jsonplaceholder.typicode.com/posts",data={'userid':2,id:200})
print(response)
print(response.text)
# Out:
# <Response [201]>
# {
#   "userid": "2",
#   "<built-in function id>": "200",
#   "id": 101
# }
