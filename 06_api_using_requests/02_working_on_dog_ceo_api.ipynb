# %%
import requests
import json

# %%
response = requests.get('https://dog.ceo/api/breeds/list/all')

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'https://dog.ceo/api/breeds/list/all'

# %%
response.text
# Out:
# '{"message":{"affenpinscher":[],"african":["wild"],"airedale":[],"akita":[],"appenzeller":[],"australian":["kelpie","shepherd"],"bakharwal":["indian"],"basenji":[],"beagle":[],"bluetick":[],"borzoi":[],"bouvier":[],"boxer":[],"brabancon":[],"briard":[],"buhund":["norwegian"],"bulldog":["boston","english","french"],"bullterrier":["staffordshire"],"cattledog":["australian"],"cavapoo":[],"chihuahua":[],"chippiparai":["indian"],"chow":[],"clumber":[],"cockapoo":[],"collie":["border"],"coonhound":[],"corgi":["cardigan"],"cotondetulear":[],"dachshund":[],"dalmatian":[],"dane":["great"],"danish":["swedish"],"deerhound":["scottish"],"dhole":[],"dingo":[],"doberman":[],"elkhound":["norwegian"],"entlebucher":[],"eskimo":[],"finnish":["lapphund"],"frise":["bichon"],"gaddi":["indian"],"german":["shepherd"],"greyhound":["indian","italian"],"groenendael":[],"havanese":[],"hound":["afghan","basset","blood","english","ibizan","plott","walker"],"husky":[],"keeshond":[],"kelpie":[],"kombai":[],"komond
# ...

# %%
# instead of json loads we can use response.json() which is in requests and exactlly same

data1= json.loads(response.text)
print(data1)
print()
data=response.json()
print(data)
# Out:
# {'message': {'affenpinscher': [], 'african': ['wild'], 'airedale': [], 'akita': [], 'appenzeller': [], 'australian': ['kelpie', 'shepherd'], 'bakharwal': ['indian'], 'basenji': [], 'beagle': [], 'bluetick': [], 'borzoi': [], 'bouvier': [], 'boxer': [], 'brabancon': [], 'briard': [], 'buhund': ['norwegian'], 'bulldog': ['boston', 'english', 'french'], 'bullterrier': ['staffordshire'], 'cattledog': ['australian'], 'cavapoo': [], 'chihuahua': [], 'chippiparai': ['indian'], 'chow': [], 'clumber': [], 'cockapoo': [], 'collie': ['border'], 'coonhound': [], 'corgi': ['cardigan'], 'cotondetulear': [], 'dachshund': [], 'dalmatian': [], 'dane': ['great'], 'danish': ['swedish'], 'deerhound': ['scottish'], 'dhole': [], 'dingo': [], 'doberman': [], 'elkhound': ['norwegian'], 'entlebucher': [], 'eskimo': [], 'finnish': ['lapphund'], 'frise': ['bichon'], 'gaddi': ['indian'], 'german': ['shepherd'], 'greyhound': ['indian', 'italian'], 'groenendael': [], 'havanese': [], 'hound': ['afghan', 'basset', 
# ...

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
# printig breeds and sub breeds

for key,value in data["message"].items():
    print(key,":",len(value),value)
# Out:
# affenpinscher : 0 []
# african : 1 ['wild']
# airedale : 0 []
# akita : 0 []
# appenzeller : 0 []
# australian : 2 ['kelpie', 'shepherd']
# bakharwal : 1 ['indian']
# basenji : 0 []
# beagle : 0 []
# bluetick : 0 []
# borzoi : 0 []
# bouvier : 0 []
# boxer : 0 []
# brabancon : 0 []
# briard : 0 []
# buhund : 1 ['norwegian']
# bulldog : 3 ['boston', 'english', 'french']
# bullterrier : 1 ['staffordshire']
# cattledog : 1 ['australian']
# cavapoo : 0 []
# chihuahua : 0 []
# chippiparai : 1 ['indian']
# chow : 0 []
# clumber : 0 []
# cockapoo : 0 []
# collie : 1 ['border']
# coonhound : 0 []
# corgi : 1 ['cardigan']
# cotondetulear : 0 []
# dachshund : 0 []
# dalmatian : 0 []
# dane : 1 ['great']
# danish : 1 ['swedish']
# deerhound : 1 ['scottish']
# dhole : 0 []
# dingo : 0 []
# doberman : 0 []
# elkhound : 1 ['norwegian']
# entlebucher : 0 []
# eskimo : 0 []
# finnish : 1 ['lapphund']
# frise : 1 ['bichon']
# gaddi : 1 ['indian']
# german : 1 ['shepherd']
# ...

# %%
#printing over list of sub breeds

for i in data["message"]["hound"]:
    print(i)
# Out:
# afghan
# basset
# blood
# english
# ibizan
# plott
# walker

# %%
for i in data["message"]["spaniel"]:
    print(i)
# Out:
# blenheim
# brittany
# cocker
# irish
# japanese
# sussex
# welsh
