# %%
import requests
import json

# %%
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"message": "success", "timestamp": 1761623893, "iss_position": {"longitude": "84.8709", "latitude": "8.6507"}}'

# %%
response.headers
# Out:
# {'Server': 'nginx/1.10.3', 'Date': 'Tue, 28 Oct 2025 03:58:14 GMT', 'Content-Type': 'application/json', 'Content-Length': '111', 'Connection': 'keep-alive', 'access-control-allow-origin': '*'}

# %% [markdown]
# # content type

# %%
a = requests.get('https://codingninjas.in/api/v3/events')
print(a.status_code)
# Out:
# 200

# %%
a.headers
# Out:
# {'Content-Type': 'text/html', 'Last-Modified': 'Fri, 24 Oct 2025 11:52:34 GMT', 'Server': 'AmazonS3', 'Content-Encoding': 'br', 'Cache-Control': 'public,max-age=300,must-revalidate', 'ETag': 'W/"c2d2e1608e8aa6d04f8e8e24f5881823"', 'X-Amz-Cf-Pop': 'DEL51-P1', 'X-Amz-Cf-Id': '6uXwoylgRfEeBdlNQzGDZayTROFu-QOoHLqMKW6p-aFg9Uur18pfnw==', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Length': '5861', 'X-EdgeConnect-MidMile-RTT': '4', 'X-EdgeConnect-Origin-MEX-Latency': '33', 'Date': 'Tue, 28 Oct 2025 04:00:56 GMT', 'Connection': 'keep-alive', 'Set-Cookie': 'geo_country=IN; Max-Age=2592000; Path=/; domain=.naukri.com; secure; SameSite=None, _t_ds=e525fd01761624056-71e525fd0-0e525fd0; expires=Wed, 28-Oct-2026 04:00:56 GMT; path=/; domain=.naukri.com; secure; HttpOnly; SameSite=Lax', 'Strict-Transport-Security': 'max-age=31536000 ; includeSubDomains ; preload'}

# %%
header_info=a.headers

print(header_info['content-type'])
# Out:
# text/html

# %% [markdown]
# # hound sub breeds

# %%
b= requests.get('https://dog.ceo/api/breeds/list/all')
print(b.status_code)
# Out:
# 200

# %%
breeds_info = b.json() #converting to python

# %%
hound_sub = breeds_info['message']['hound']

# %%
hound_sub
# Out:
# ['afghan', 'basset', 'blood', 'english', 'ibizan', 'plott', 'walker']

# %%
for i in hound_sub:
    print(i)
# Out:
# afghan
# basset
# blood
# english
# ibizan
# plott
# walker

# %% [markdown]
# # poodlle sub breeds count

# %%
poodle_sub = breeds_info['message']['poodle']
print(len(poodle_sub))
# Out:
# 4

# %% [markdown]
# # Title of courses

# %%
c=requests.get('https://codingninjas.in/api/v3/courses')
print(c.status_code)
# Out:
# 200

# %%
c.encoding
# Out:
# 'ISO-8859-1'

# %%
c.headers
# Out:
# {'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Tue, 28 Oct 2025 04:08:26 GMT', 'Cache-Control': 'must-revalidate, max-age=300', 'Last-Modified': 'Fri, 24 Oct 2025 11:37:53 GMT', 'Server': 'AmazonS3', 'Set-Cookie': 'geo_country=IN; Max-Age=2592000; Path=/; domain=.codingninjas.com; secure; SameSite=None', 'Content-Encoding': 'br', 'ETag': 'W/"d92c96e3f80b98f62292ecf58a7f4f84"', 'Vary': 'Accept-Encoding', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 cc35ef9ae729466b0fe3cddcf48ff56a.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'DEL51-P5', 'Alt-Svc': 'h3=":443"; ma=86400', 'X-Amz-Cf-Id': '2KqmRa91OUmaHAa1ymA-HNJmxge4EBX_cX8z0iH_SUsgw-IFvwYf4w==', 'Age': '220'}

# %%
# as we are not getting json data from coding ninja site

# %%
d=requests.get('https://swapi.co/api/planets')
print(d.status_code)
# Out:
# 200

# %%
d.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '82', 'Connection': 'keep-alive', 'Date': 'Tue, 28 Oct 2025 04:15:28 GMT', 'ETag': 'W/"52-g+JHrps1EUPMWbZ2dO6N5YLKsJQ"', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 11610a2a34c33a7dc259335c0a614c9e.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'DEL54-P4', 'X-Amz-Cf-Id': 'rsfxQN_m-DpojdEJFE_HKJf4SXk9kAZn9H5APwZq7m5o-LXKXbKH7g=='}

# %%
d.text
# Out:
# 'Endpoint not meant for programmatic use. Returning 200 to reduce possible burden.\n'

# %% [markdown]
# # holiday api

# %%
e=requests.get('https://holidayapi.com/')
print(e.status_code)
# Out:
# 403

# %%
# api_key = 2bb8f976-1e33-49cd-9e5a-f9fe0c41ddf6

e=requests.get('https://holidayapi.com/v1/holidays',params={'key':'2bb8f976-1e33-49cd-9e5a-f9fe0c41ddf6','country':'IN','year':'2024'})
print(e.status_code)
# Out:
# 200

# %%
e.text
# Out:
# '{"status":200,"warning":"These results do not include state and province holidays. For more information, please visit https:\\/\\/holidayapi.com\\/docs","requests":{"used":2,"available":9998,"resets":"2025-11-01 00:00:00"},"holidays":[{"name":"Republic Day","date":"2024-01-26","observed":"2024-01-26","public":true,"country":"IN","uuid":"2e10b51e-08a0-4595-a234-f2cf0a1d0863","weekday":{"date":{"name":"Friday","numeric":"5"},"observed":{"name":"Friday","numeric":"5"}}},{"name":"Valentine\'s Day","date":"2024-02-14","observed":"2024-02-14","public":false,"country":"IN","uuid":"0e6de01c-da87-4530-9fa4-d572feee3fa9","weekday":{"date":{"name":"Wednesday","numeric":"3"},"observed":{"name":"Wednesday","numeric":"3"}}},{"name":"March Equinox","date":"2024-03-20","observed":"2024-03-20","public":false,"country":"IN","uuid":"154cb189-4316-46dc-b982-fb9d743ba81f","weekday":{"date":{"name":"Wednesday","numeric":"3"},"observed":{"name":"Wednesday","numeric":"3"}}},{"name":"Bank Holiday","date":"2
# ...

# %%
e.headers
# Out:
# {'Date': 'Tue, 28 Oct 2025 04:37:36 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"cf-nel","success_fraction":0.0,"max_age":604800}', 'Access-Control-Allow-Origin': '*', 'cf-cache-status': 'DYNAMIC', 'X-Content-Type-Options': 'nosniff', 'Report-To': '{"group":"cf-nel","max_age":604800,"endpoints":[{"url":"https://a.nel.cloudflare.com/report/v4?s=RNAv9vZx0kS81K5AHgQc%2FqGDEXKF3Ewm%2B66KKEqr7uuuICWYXiDv92ev9JLTNPIwz%2FxnLxodJdTHFLTHnZRPo%2BEToWgGMMwLGN2wsruUznSCxlK5%2BV1Q53PO"}]}', 'Content-Encoding': 'br', 'Server': 'cloudflare', 'CF-RAY': '9957bd24ce9ae1ac-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
e.url
# Out:
# 'https://holidayapi.com/v1/holidays?key=2bb8f976-1e33-49cd-9e5a-f9fe0c41ddf6&country=IN&year=2024'

# %%
data = e.json()

# %%
holidays_data= data['holidays']

# %%
type(holidays_data)
# Out:
# list

# %%
for i in holidays_data:
    print(i['name'])
# Out:
# Republic Day
# Valentine's Day
# March Equinox
# Bank Holiday
# Doctor Ambedkar's Birthday
# Mother's Day
# Father's Day
# June Solstice
# Friendship Day
# Independence Day
# September Equinox
# Mahatma Gandhi's Birthday
# December Solstice

# %%
for i in holidays_data:
    if i['date']=='2024-10-02':
        print(i['name'])
        break
# Out:
# Mahatma Gandhi's Birthday
