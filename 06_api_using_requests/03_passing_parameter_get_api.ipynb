# %%
import requests

# %%
a= requests.get("https://api.openaq.org/v3/countries")
a.status_code
# Out:
# 401

# %%
# requests.get("url",params = {key:value pairs})

# %%
#b= requests.get('https://www.metaweather.com/api/location/search/',params={"quary":"Delhi"})
#b.status_code

# %%
a=requests.get("https://api.nasa.gov/planetary/apod",params= {"api_key":"DEMO_KEY"})
a.status_code
# Out:
# 200

# %%
a.url
# Out:
# 'https://api.nasa.gov/planetary/apod?api_key=DEMO_KEY'

# %%
#api_key authentication indentity
