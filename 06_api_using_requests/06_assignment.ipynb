# %%
import requests
import json

# %%
with open('events.json','r') as file_obj:
    data = json.load(file_obj)

# %%
events = data['data']['events']

# %%
for i in events:
    print(i['name'])
    print(i['short_desc'])
    print()
# Out:
# Freshmen Induction at Delhi Technological University
# Give your career a head-start and know how you can get closer to your dream job by refining your coding skills.
#
# Webinar on Career Camp
# Join us live for a webinar on Career Camp by our Co-Founder Ankush Singla on 30th December at 7 PM.
#
# World Programming Championship  -  IIT Mumbai | TechFest
# Put on your coding caps as Techfest and STL in association with Coding Ninjas brings to you the World Programming Championship.
#
# How to Prepare for Placement interviews?
# Join us live for an interesting interaction with Coding Ninjas Industry Mentors to know the tips and tricks to crack placement interviews on 26th December at 8 PM
#
# Freshmen Induction at PEC, Chandigarh
# Give your career a head-start and know how you can get closer to your dream job by refining your coding skills.
#
# Freshmen Induction at VIT Chennai
# ...
