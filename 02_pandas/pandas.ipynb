# %% [raw]
# a python lib(module)....manipulate data in ML
#
# behaves like xL file
#
# dataframe----

# %%
import pandas as pd

# %%
iris=pd.read_csv("iris.csv")          #read_json , read_xl , read html

# %%
iris
# Out:
#      5.1  3.5  1.4   .2     Setosa
# 0    4.9  3.0  1.4  0.2     Setosa
# 1    4.7  3.2  1.3  0.2     Setosa
# 2    4.6  3.1  1.5  0.2     Setosa
# 3    5.0  3.6  1.4  0.2     Setosa
# 4    5.4  3.9  1.7  0.4     Setosa
# ..   ...  ...  ...  ...        ...
# 144  6.7  3.0  5.2  2.3  Virginica
# 145  6.3  2.5  5.0  1.9  Virginica
# 146  6.5  3.0  5.2  2.0  Virginica
# 147  6.2  3.4  5.4  2.3  Virginica
# 148  5.9  3.0  5.1  1.8  Virginica
#
# [149 rows x 5 columns]

# %%
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#df=iris   #any change happen in any refereneone reflect in both as both will contain 

df=iris.copy()   #a new memory spce will be created (now both have diff ref)

# %%
df.head()
# Out:
#    5.1  3.5  1.4   .2  Setosa
# 0  4.9  3.0  1.4  0.2  Setosa
# 1  4.7  3.2  1.3  0.2  Setosa
# 2  4.6  3.1  1.5  0.2  Setosa
# 3  5.0  3.6  1.4  0.2  Setosa
# 4  5.4  3.9  1.7  0.4  Setosa

# %%
df.head(3)
# Out:
#    5.1  3.5  1.4   .2  Setosa
# 0  4.9  3.0  1.4  0.2  Setosa
# 1  4.7  3.2  1.3  0.2  Setosa
# 2  4.6  3.1  1.5  0.2  Setosa

# %%
df.tail()
# Out:
#      5.1  3.5  1.4   .2     Setosa
# 144  6.7  3.0  5.2  2.3  Virginica
# 145  6.3  2.5  5.0  1.9  Virginica
# 146  6.5  3.0  5.2  2.0  Virginica
# 147  6.2  3.4  5.4  2.3  Virginica
# 148  5.9  3.0  5.1  1.8  Virginica

# %%
df.tail(6)
# Out:
#      5.1  3.5  1.4   .2     Setosa
# 143  6.7  3.3  5.7  2.5  Virginica
# 144  6.7  3.0  5.2  2.3  Virginica
# 145  6.3  2.5  5.0  1.9  Virginica
# 146  6.5  3.0  5.2  2.0  Virginica
# 147  6.2  3.4  5.4  2.3  Virginica
# 148  5.9  3.0  5.1  1.8  Virginica

# %%
df.columns   #print column header
# Out:
# Index(['5.1', '3.5', '1.4', '.2', 'Setosa'], dtype='object')

# %%
df.index #print labels
# Out:
# RangeIndex(start=0, stop=149, step=1)

# %%
#changing column headers

df.columns=["sl","sw","pl",'pw','flower_type']

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.9  3.0  1.4  0.2      Setosa
# 1  4.7  3.2  1.3  0.2      Setosa
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 4  5.4  3.9  1.7  0.4      Setosa

# %%
df.shape
# Out:
# (149, 5)

# %%
df.dtypes
# Out:
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.054362    3.773826    1.206040
# std      0.828594    0.435810    1.760543    0.760354
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [raw]
# they all not consider NaN
#
# 25 percentile----what is the value for which 25% of the total values comes under it
#
# here 25percentile_score = 5.1 means 25% values are less than it
#
# eg if 25%_score=0
#       50%_score=0
#       75%_score=0
#       100%_score=1   this tells most of data is 0

# %%
#accesing particular column

df.sl #or df['sl']
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw  flower_type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]

# %%
df.isnull().sum()  #column wise no of null values
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
#taking slice of data

#df[1:4,2:4]-----give error
df.iloc[1:4,2:4]
# Out:
#     pl   pw
# 1  1.3  0.2
# 2  1.5  0.2
# 3  1.4  0.2

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.9  3.0  1.4  0.2      Setosa
# 1  4.7  3.2  1.3  0.2      Setosa
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 4  5.4  3.9  1.7  0.4      Setosa

# %% [raw]
# lebels= 0 1 2 3 4

# %%
df.drop(0)  #del 0 lebel row
# Out:
#       sl   sw   pl   pw flower_type
# 1    4.7  3.2  1.3  0.2      Setosa
# 2    4.6  3.1  1.5  0.2      Setosa
# 3    5.0  3.6  1.4  0.2      Setosa
# 4    5.4  3.9  1.7  0.4      Setosa
# 5    4.6  3.4  1.4  0.3      Setosa
# ..   ...  ...  ...  ...         ...
# 144  6.7  3.0  5.2  2.3   Virginica
# 145  6.3  2.5  5.0  1.9   Virginica
# 146  6.5  3.0  5.2  2.0   Virginica
# 147  6.2  3.4  5.4  2.3   Virginica
# 148  5.9  3.0  5.1  1.8   Virginica
#
# [148 rows x 5 columns]

# %%
df.drop(4,inplace=True)

# %%
a=df.drop(0) ##makes copy of df in a by excluding 0 th row
a.head()
# Out:
#     sl   sw   pl   pw flower_type
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 5  4.6  3.4  1.4  0.3      Setosa
# 6  5.0  3.4  1.5  0.2      Setosa
# 7  4.4  2.9  1.4  0.2      Setosa

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.9  3.0  1.4  0.2      Setosa
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 5  4.6  3.4  1.4  0.3      Setosa
# 6  5.0  3.4  1.5  0.2      Setosa

# %% [raw]
# label vs position
# drop work with labels

# %%
df.index  # print all labels
# Out:
# Int64Index([  0,   2,   3,   5,   6,   7,   8,   9,  10,  11,
#             ...
#             139, 140, 141, 142, 143, 144, 145, 146, 147, 148],
#            dtype='int64', length=147)

# %%
#return labels of position......df.index[position]
df.index[0],df.index[4]
# Out:
# (0, 6)

# %%
#drop by position
df.drop(df.index[0]) #drop at 0th position 

#below is the output of returned value not after droping
# Out:
#       sl   sw   pl   pw flower_type
# 2    4.6  3.1  1.5  0.2      Setosa
# 3    5.0  3.6  1.4  0.2      Setosa
# 5    4.6  3.4  1.4  0.3      Setosa
# 6    5.0  3.4  1.5  0.2      Setosa
# 7    4.4  2.9  1.4  0.2      Setosa
# ..   ...  ...  ...  ...         ...
# 144  6.7  3.0  5.2  2.3   Virginica
# 145  6.3  2.5  5.0  1.9   Virginica
# 146  6.5  3.0  5.2  2.0   Virginica
# 147  6.2  3.4  5.4  2.3   Virginica
# 148  5.9  3.0  5.1  1.8   Virginica
#
# [146 rows x 5 columns]

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.9  3.0  1.4  0.2      Setosa
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 5  4.6  3.4  1.4  0.3      Setosa
# 6  5.0  3.4  1.5  0.2      Setosa

# %%
df.drop(df.index[0],inplace=True)

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 5  4.6  3.4  1.4  0.3      Setosa
# 6  5.0  3.4  1.5  0.2      Setosa
# 7  4.4  2.9  1.4  0.2      Setosa

# %%
df.drop(df.index[0],inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 3  5.0  3.6  1.4  0.2      Setosa
# 5  4.6  3.4  1.4  0.3      Setosa
# 6  5.0  3.4  1.5  0.2      Setosa
# 7  4.4  2.9  1.4  0.2      Setosa
# 8  4.9  3.1  1.5  0.1      Setosa

# %%
#droping at multiple positions

df.drop(df.index[[0,3]],inplace=True)  #del at position 0 and 3 (not from 0 to 3)
df.head()
# Out:
#      sl   sw   pl   pw flower_type
# 5   4.6  3.4  1.4  0.3      Setosa
# 6   5.0  3.4  1.5  0.2      Setosa
# 8   4.9  3.1  1.5  0.1      Setosa
# 9   5.4  3.7  1.5  0.2      Setosa
# 10  4.8  3.4  1.6  0.2      Setosa

# %%
df.drop(df.index[[0,1,2,3]],inplace=True)  #drop from osition 0 1 2 3
df.head()
# Out:
#      sl   sw   pl   pw flower_type
# 10  4.8  3.4  1.6  0.2      Setosa
# 11  4.8  3.0  1.4  0.1      Setosa
# 12  4.3  3.0  1.1  0.1      Setosa
# 13  5.8  4.0  1.2  0.2      Setosa
# 14  5.7  4.4  1.5  0.4      Setosa

# %%
df.sl>5  #checking conditions across row
# Out:
# 10     False
# 11     False
# 12     False
# 13      True
# 14      True
#        ...
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# Name: sl, Length: 139, dtype: bool

# %%
df[df.sl>5] #return rows satisfying condition like boolean arr
# Out:
#       sl   sw   pl   pw flower_type
# 13   5.8  4.0  1.2  0.2      Setosa
# 14   5.7  4.4  1.5  0.4      Setosa
# 15   5.4  3.9  1.3  0.4      Setosa
# 16   5.1  3.5  1.4  0.3      Setosa
# 17   5.7  3.8  1.7  0.3      Setosa
# ..   ...  ...  ...  ...         ...
# 144  6.7  3.0  5.2  2.3   Virginica
# 145  6.3  2.5  5.0  1.9   Virginica
# 146  6.5  3.0  5.2  2.0   Virginica
# 147  6.2  3.4  5.4  2.3   Virginica
# 148  5.9  3.0  5.1  1.8   Virginica
#
# [115 rows x 5 columns]

# %%
df[df.flower_type=="Setosa"].describe()
# Out:
#               sl         sw         pl         pw
# count  39.000000  39.000000  39.000000  39.000000
# mean    5.033333   3.451282   1.464103   0.253846
# std     0.360068   0.395948   0.189858   0.112029
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.200000   1.350000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %%
# iloc and head work by position
print(df.head())
print(df.iloc[0:5])
#print(df.loc[0])   #work by label---give error as 0 label is deleted
print(df.loc[10]) 
print(df.loc[10:12])  #here last is included
# Out:
#      sl   sw   pl   pw flower_type
# 10  4.8  3.4  1.6  0.2      Setosa
# 11  4.8  3.0  1.4  0.1      Setosa
# 12  4.3  3.0  1.1  0.1      Setosa
# 13  5.8  4.0  1.2  0.2      Setosa
# 14  5.7  4.4  1.5  0.4      Setosa
#      sl   sw   pl   pw flower_type
# 10  4.8  3.4  1.6  0.2      Setosa
# 11  4.8  3.0  1.4  0.1      Setosa
# 12  4.3  3.0  1.1  0.1      Setosa
# 13  5.8  4.0  1.2  0.2      Setosa
# 14  5.7  4.4  1.5  0.4      Setosa
# sl                4.8
# sw                3.4
# pl                1.6
# pw                0.2
# flower_type    Setosa
# Name: 10, dtype: object
#      sl   sw   pl   pw flower_type
# 10  4.8  3.4  1.6  0.2      Setosa
# 11  4.8  3.0  1.4  0.1      Setosa
# 12  4.3  3.0  1.1  0.1      Setosa

# %%
# add a row
df.loc[0]=[1,2,3,4,"Setosa"]  #add at end with 0 label

# %%
df.tail()
# Out:
#       sl   sw   pl   pw flower_type
# 145  6.3  2.5  5.0  1.9   Virginica
# 146  6.5  3.0  5.2  2.0   Virginica
# 147  6.2  3.4  5.4  2.3   Virginica
# 148  5.9  3.0  5.1  1.8   Virginica
# 0    1.0  2.0  3.0  4.0      Setosa

# %%
df.loc[149]=[1,2,3,4,"Setosa"]
df.tail()
# Out:
#       sl   sw   pl   pw flower_type
# 146  6.5  3.0  5.2  2.0   Virginica
# 147  6.2  3.4  5.4  2.3   Virginica
# 148  5.9  3.0  5.1  1.8   Virginica
# 0    1.0  2.0  3.0  4.0      Setosa
# 149  1.0  2.0  3.0  4.0      Setosa

# %%
#reset the index
df.reset_index(drop=True,inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=141, step=1)

# %%
df.reset_index() #without drop=True a new column index will created
#below is tell what it will return, not the current condition of df
# Out:
#      index   sl   sw   pl   pw flower_type
# 0        0  4.8  3.4  1.6  0.2      Setosa
# 1        1  4.8  3.0  1.4  0.1      Setosa
# 2        2  4.3  3.0  1.1  0.1      Setosa
# 3        3  5.8  4.0  1.2  0.2      Setosa
# 4        4  5.7  4.4  1.5  0.4      Setosa
# ..     ...  ...  ...  ...  ...         ...
# 136    136  6.5  3.0  5.2  2.0   Virginica
# 137    137  6.2  3.4  5.4  2.3   Virginica
# 138    138  5.9  3.0  5.1  1.8   Virginica
# 139    139  1.0  2.0  3.0  4.0      Setosa
# 140    140  1.0  2.0  3.0  4.0      Setosa
#
# [141 rows x 6 columns]

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.8  3.4  1.6  0.2      Setosa
# 1  4.8  3.0  1.4  0.1      Setosa
# 2  4.3  3.0  1.1  0.1      Setosa
# 3  5.8  4.0  1.2  0.2      Setosa
# 4  5.7  4.4  1.5  0.4      Setosa

# %%
#how to delete column
df.drop('sl',axis=1)  #axis=1 means column  "sl"---tells which label to delete
# Out:
#       sw   pl   pw flower_type
# 0    3.4  1.6  0.2      Setosa
# 1    3.0  1.4  0.1      Setosa
# 2    3.0  1.1  0.1      Setosa
# 3    4.0  1.2  0.2      Setosa
# 4    4.4  1.5  0.4      Setosa
# ..   ...  ...  ...         ...
# 136  3.0  5.2  2.0   Virginica
# 137  3.4  5.4  2.3   Virginica
# 138  3.0  5.1  1.8   Virginica
# 139  2.0  3.0  4.0      Setosa
# 140  2.0  3.0  4.0      Setosa
#
# [141 rows x 4 columns]

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.8  3.4  1.6  0.2      Setosa
# 1  4.8  3.0  1.4  0.1      Setosa
# 2  4.3  3.0  1.1  0.1      Setosa
# 3  5.8  4.0  1.2  0.2      Setosa
# 4  5.7  4.4  1.5  0.4      Setosa

# %%
df.drop('sl',axis=1,inplace=True)
df.head()
# Out:
#     sw   pl   pw flower_type
# 0  3.4  1.6  0.2      Setosa
# 1  3.0  1.4  0.1      Setosa
# 2  3.0  1.1  0.1      Setosa
# 3  4.0  1.2  0.2      Setosa
# 4  4.4  1.5  0.4      Setosa

# %%
# another way to del a column

del df['sw']

# %%
df.head()
# Out:
#     pl   pw flower_type
# 0  1.6  0.2      Setosa
# 1  1.4  0.1      Setosa
# 2  1.1  0.1      Setosa
# 3  1.2  0.2      Setosa
# 4  1.5  0.4      Setosa

# %%
#re copying the data
df=iris.copy()
df.columns=["sl","sw","pl",'pw','flower_type']
df.head()
# Out:
#     sl   sw   pl   pw flower_type
# 0  4.9  3.0  1.4  0.2      Setosa
# 1  4.7  3.2  1.3  0.2      Setosa
# 2  4.6  3.1  1.5  0.2      Setosa
# 3  5.0  3.6  1.4  0.2      Setosa
# 4  5.4  3.9  1.7  0.4      Setosa

# %%
#adding a column

df["dif_pl_pw"]=df['pl']-df['pw']  #works directy at original df
df.tail()
# Out:
#       sl   sw   pl   pw flower_type  dif_pl_pw
# 144  6.7  3.0  5.2  2.3   Virginica        2.9
# 145  6.3  2.5  5.0  1.9   Virginica        3.1
# 146  6.5  3.0  5.2  2.0   Virginica        3.2
# 147  6.2  3.4  5.4  2.3   Virginica        3.1
# 148  5.9  3.0  5.1  1.8   Virginica        3.3

# %%
df["abc"]=1

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.0  1.4  0.2      Setosa        1.2    1
# 1  4.7  3.2  1.3  0.2      Setosa        1.1    1
# 2  4.6  3.1  1.5  0.2      Setosa        1.3    1
# 3  5.0  3.6  1.4  0.2      Setosa        1.2    1
# 4  5.4  3.9  1.7  0.4      Setosa        1.3    1

# %% [markdown]
# # Handling NaN

# %% [raw]
# 2 options
#
# remove entire row
# replace vaues with mean,median,etc based on conditin

# %%
df
# Out:
#       sl   sw   pl   pw flower_type  dif_pl_pw  abc
# 0    4.9  3.0  1.4  0.2      Setosa        1.2    1
# 1    4.7  3.2  1.3  0.2      Setosa        1.1    1
# 2    4.6  3.1  1.5  0.2      Setosa        1.3    1
# 3    5.0  3.6  1.4  0.2      Setosa        1.2    1
# 4    5.4  3.9  1.7  0.4      Setosa        1.3    1
# ..   ...  ...  ...  ...         ...        ...  ...
# 144  6.7  3.0  5.2  2.3   Virginica        2.9    1
# 145  6.3  2.5  5.0  1.9   Virginica        3.1    1
# 146  6.5  3.0  5.2  2.0   Virginica        3.2    1
# 147  6.2  3.4  5.4  2.3   Virginica        3.1    1
# 148  5.9  3.0  5.1  1.8   Virginica        3.3    1
#
# [149 rows x 7 columns]

# %%
#to make specific entries 0

df.iloc[2:4,1:3]=0

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.0  1.4  0.2      Setosa        1.2    1
# 1  4.7  3.2  1.3  0.2      Setosa        1.1    1
# 2  4.6  0.0  0.0  0.2      Setosa        1.3    1
# 3  5.0  0.0  0.0  0.2      Setosa        1.2    1
# 4  5.4  3.9  1.7  0.4      Setosa        1.3    1

# %%
#to make specific entries NaN we need numpy
import numpy as np

df.iloc[2:4,1:3]=np.NaN

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.0  1.4  0.2      Setosa        1.2    1
# 1  4.7  3.2  1.3  0.2      Setosa        1.1    1
# 2  4.6  NaN  NaN  0.2      Setosa        1.3    1
# 3  5.0  NaN  NaN  0.2      Setosa        1.2    1
# 4  5.4  3.9  1.7  0.4      Setosa        1.3    1

# %%
df.describe()
# Out:
#                sl         sw          pl          pw   dif_pl_pw    abc
# count  149.000000  147.00000  147.000000  149.000000  149.000000  149.0
# mean     5.848322    3.05034    3.805442    1.206040    2.567785    1.0
# std      0.828594    0.43642    1.751273    0.760354    1.049277    0.0
# min      4.300000    2.00000    1.000000    0.100000    0.800000    1.0
# 25%      5.100000    2.80000    1.600000    0.300000    1.300000    1.0
# 50%      5.800000    3.00000    4.400000    1.300000    2.900000    1.0
# 75%      6.400000    3.30000    5.100000    1.800000    3.300000    1.0
# max      7.900000    4.40000    6.900000    2.500000    4.700000    1.0

# %%
#handling NaN by droping row

df.dropna(inplace=True)

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.0  1.4  0.2      Setosa        1.2    1
# 1  4.7  3.2  1.3  0.2      Setosa        1.1    1
# 4  5.4  3.9  1.7  0.4      Setosa        1.3    1
# 5  4.6  3.4  1.4  0.3      Setosa        1.1    1
# 6  5.0  3.4  1.5  0.2      Setosa        1.3    1

# %%
df.reset_index(drop=True,inplace=True)  
df.iloc[2:4,1:3]=np.NaN   #creating nan again after reseting index

# %%
df.head()
# Out:
#     sl   sw   pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.0  1.4  0.2      Setosa        1.2    1
# 1  4.7  3.2  1.3  0.2      Setosa        1.1    1
# 2  5.4  NaN  NaN  0.4      Setosa        1.3    1
# 3  4.6  NaN  NaN  0.3      Setosa        1.1    1
# 4  5.0  3.4  1.5  0.2      Setosa        1.3    1

# %%
#handling nan by replacing with other value

#replacing with mean
df.sw.fillna(df.sw.mean(),inplace=True)
df.head()
# Out:
#     sl        sw   pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.000000  1.4  0.2      Setosa        1.2    1
# 1  4.7  3.200000  1.3  0.2      Setosa        1.1    1
# 2  5.4  3.042069  NaN  0.4      Setosa        1.3    1
# 3  4.6  3.042069  NaN  0.3      Setosa        1.1    1
# 4  5.0  3.400000  1.5  0.2      Setosa        1.3    1

# %%
df.pl.fillna(df.pl.mean(),inplace=True)
df.head()
# Out:
#     sl        sw        pl   pw flower_type  dif_pl_pw  abc
# 0  4.9  3.000000  1.400000  0.2      Setosa        1.2    1
# 1  4.7  3.200000  1.300000  0.2      Setosa        1.1    1
# 2  5.4  3.042069  3.836552  0.4      Setosa        1.3    1
# 3  4.6  3.042069  3.836552  0.3      Setosa        1.1    1
# 4  5.0  3.400000  1.500000  0.2      Setosa        1.3    1

# %%
#df.pl.fillna(df[df.flower_type=="Setosa"].pl.mean())

# %% [markdown]
# # Handling strings

# %% [raw]
# we need to convert strings to numeric to perform calculation

# %%
df["Gender"]="Female"

# %%
df.head()
# Out:
#     sl        sw        pl   pw flower_type  dif_pl_pw  abc  Gender
# 0  4.9  3.000000  1.400000  0.2      Setosa        1.2    1  Female
# 1  4.7  3.200000  1.300000  0.2      Setosa        1.1    1  Female
# 2  5.4  3.042069  3.836552  0.4      Setosa        1.3    1  Female
# 3  4.6  3.042069  3.836552  0.3      Setosa        1.1    1  Female
# 4  5.0  3.400000  1.500000  0.2      Setosa        1.3    1  Female

# %%
df.iloc[0:10,7]="Male"

# %%
df.head()
# Out:
#     sl        sw        pl   pw flower_type  dif_pl_pw   abc Gender
# 0  4.9  3.000000  1.400000  0.2      Setosa        1.2  Male   Male
# 1  4.7  3.200000  1.300000  0.2      Setosa        1.1  Male   Male
# 2  5.4  3.042069  3.836552  0.4      Setosa        1.3  Male   Male
# 3  4.6  3.042069  3.836552  0.3      Setosa        1.1  Male   Male
# 4  5.0  3.400000  1.500000  0.2      Setosa        1.3  Male   Male

# %%
def f(s):
    if s=="Male":
        return 0
    else:
        return 1

df["sex"]=df.Gender.apply(f)
df.head()
# Out:
#     sl        sw        pl   pw flower_type  dif_pl_pw   abc Gender  sex
# 0  4.9  3.000000  1.400000  0.2      Setosa        1.2  Male   Male    0
# 1  4.7  3.200000  1.300000  0.2      Setosa        1.1  Male   Male    0
# 2  5.4  3.042069  3.836552  0.4      Setosa        1.3  Male   Male    0
# 3  4.6  3.042069  3.836552  0.3      Setosa        1.1  Male   Male    0
# 4  5.0  3.400000  1.500000  0.2      Setosa        1.3  Male   Male    0

# %%
del df["Gender"]
df.head()
# Out:
#     sl        sw        pl   pw flower_type  dif_pl_pw   abc  sex
# 0  4.9  3.000000  1.400000  0.2      Setosa        1.2  Male    0
# 1  4.7  3.200000  1.300000  0.2      Setosa        1.1  Male    0
# 2  5.4  3.042069  3.836552  0.4      Setosa        1.3  Male    0
# 3  4.6  3.042069  3.836552  0.3      Setosa        1.1  Male    0
# 4  5.0  3.400000  1.500000  0.2      Setosa        1.3  Male    0
