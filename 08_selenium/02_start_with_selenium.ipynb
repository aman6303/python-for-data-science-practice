# %%
from selenium import webdriver

# %%
# starting the session
#no need to pass executable_path=''  if we downloaded automatically using code
# if manually then specify path of driver
driver=webdriver.Chrome()
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="4d2d2484a77f7aa27d326ee214ad174d")>

# %% [markdown]
# # Browser Interaction

# %%
#visiting a site
driver.get('https://www.codingninjas.com/')

# %%
#getting title of page(site)
driver.title
# Out:
# 'Coding Ninjas - Get the career you deserve, faster'

# %%
# click on bac button of browser-- work on history of browser
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('savedusingdriver.png') #saved in currnt folder
# Out:
# True

# %%
#getting html of current page

driver.page_source
# Out:
# '<html lang="en" data-beasties-container=""><head><meta charset="utf-8"><title>Coding Ninjas - Get the career you deserve, faster</title><meta name="google-site-verification" content="ASe_HQRsu8j61tGt95RROjXi07M380nMuoJ0Mu9rytk"><meta name="title" content="Coding Ninjas - Get the career you deserve, faster"><meta property="og:title" content="Coding Ninjas - Get the career you deserve, faster"><meta name="description" content="8 years of delivering outcome-focused upskilling courses in a structured, practice-based format by MAANG faculty, with the fastest 1-on-1 doubt resolution."><meta property="og:description" content="8 years of delivering outcome-focused upskilling courses in a structured, practice-based format by MAANG faculty, with the fastest 1-on-1 doubt resolution."><meta name="author" content="Coding Ninjas"><meta property="og:image" content="https://files.codingninjas.com/codingninjas-.webp"><meta property="og:image:width" content="1800"><meta property="og:image:height" con
# ...

# %%
# finding link using whole text

driver.find_element_by_link_text('Certification')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 # finding link using whole text
# ----> 3 driver.find_element_by_link_text('Certification')
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_link_text'

# %% [raw]
# This AttributeError happens because the method find_element_by_link_text was removed in Selenium 4.
#
# The older find_element_by_* syntax is no longer supported.
#
# To fix this, you need to use the driver.find_element() method along with the By class.

# %% [raw]
# Old Method (Deprecated/Removed)----New Method (Selenium 4+)
# find_element_by_id(...)------find_element(By.ID, ...)
# find_element_by_name(...)-----find_element(By.NAME, ...)
# find_element_by_xpath(...)-----find_element(By.XPATH, ...)
# find_element_by_link_text(...)---find_element(By.LINK_TEXT, ...)
# find_element_by_partial_link_text(...)--find_element(By.PARTIAL_LINK_TEXT, ...)
# find_element_by_tag_name(...)----ind_element(By.TAG_NAME, ...)
# find_element_by_class_name(...)-----find_element(By.CLASS_NAME, ...)
# find_element_by_css_selector(...)-------find_element(By.CSS_SELECTOR, ...)

# %%
#importing by class
from selenium.webdriver.common.by import By

# %%
driver.find_element(By.LINK_TEXT, 'Hire from us')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4d2d2484a77f7aa27d326ee214ad174d", element="f.76EB173CA92DFA976D0307190A6DCF77.d.56E9920898D6EA69E757F541C050DCF3.e.119")>

# %%
#click on this link--- give error if link open in next tab

hire_btn=driver.find_element(By.LINK_TEXT, 'Hire from us')
hire_btn.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[16], line 3
#       1 #click on this link
#       2 hire_btn=driver.find_element(By.LINK_TEXT, 'Hire from us')
# ----> 3 hire_btn.click()
#
# File E:\Anaconda\Lib\site-packages\selenium\webdriver\remote\webelement.py:119, in WebElement.click(self)
#     111 def click(self) -> None:
#     112     """Clicks the element.
#     113
#     114     Example:
#    (...)
#     117     >>> element.click()
#     118     """
# --> 119     self._execute(Command.CLICK_ELEMENT)
#
# File E:\Anaconda\Lib\site-packages\selenium\webdriver\remote\webelement.py:572, in WebElement._execute(self, command, params)
#     570     params = {}
#     571 params["id"] = self._id
# --> 572 return self._parent.execute(command, params)
#
# ...

# %%
driver.get('https://www.selenium.dev/')

# %%
# it find first link
#not able to click on the link if it opens in new tab
#LINK_TEXT shoul be in capital

hire_btn=driver.find_element(By.LINK_TEXT, 'READ MORE') #text is case sensitive
hire_btn.click()

# %%
driver.back()

# %%
driver.forward()

# %%
# finding element by partial link text
# can find even if partial text taken from cetrre


hire_btn=driver.find_element(By.PARTIAL_LINK_TEXT, 'Doc')
hire_btn.click()

# %%
butn=driver.find_element(By.PARTIAL_LINK_TEXT, 'ocu')
butn.click()

# %%
#if link is not available----give error

#driver.find_element(By.PARTIAL_LINK_TEXT, 'Browser')

# %%
driver.maximize_window()

# %%
# driver.minimize_window()- not exists

# %%
driver.refresh()

# %%
driver.current_url

# %%
driver.get(driver.current_url)  #similar to refresh

# %%
driver.close()   # close current tab/window
