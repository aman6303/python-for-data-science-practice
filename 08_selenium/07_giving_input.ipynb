# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# searching something on google

# %%
driver= webdriver.Chrome()

# %%
driver.get('https://www.google.com/')

# %%
text_box=driver.find_element(By.NAME,'q')
text_box.send_keys("selenium")

# %%
text_box.submit()  #work only if any button type is submit

# %%
# searching any location on google map

# %%
driver.get('https://www.google.com/maps')

# %%
text_box=driver.find_element(By.NAME,'q')
text_box.send_keys("Ludhiana railway station")

# %%
# here submit button notk so we manully find i

btn=driver.find_element(By.ID,'searchbox-searchbutton')

# %%
btn.click()

# %%
driver.quit()
